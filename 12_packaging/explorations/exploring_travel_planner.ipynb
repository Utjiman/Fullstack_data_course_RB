# %% [markdown]
# # Explorations

# %%
from backend.connect_to_api import ResRobot

resrobot = ResRobot()

resrobot.access_id_from_location("Umeå")
# Out:
# Name                                               extId
# UMEÅ                                               740098065
# Umeå Centralstation                                740000190
# Umeå Busstation                                    740020461
# Umeå Östra station                                 740001581
# Umeå Vasaplan                                      740020116
# Umeå Airport                                       740025159
# Umeå Ålidhem centrum                               740023156
# Umeå Ålidhöjd                                      740045439
# Umeå Älvans väg                                    740045410
# Umeå Alviksgränd                                   740045280

# %%
resrobot.access_id_from_location("Göteborg")
# Out:
# Name                                               extId
# GÖTEBORG                                           740098001
# Göteborg Centralstation                            740000002
# Göteborg Sävenäs lokstation                        740016365
# GÖTEBORG GAMLESTADEN                               740098526
# Göteborg Korsvägen                                 740015578
# Göteborg Kungsportsplatsen                         740016358
# Göteborg Stenpiren                                 740072430
# Göteborg Eketrägatan                               740025624
# Göteborg Vårväderstorget                           740025707
# Göteborg Axel Dahlströms torg                      740025608

# %%
umea_id = 740000190
gothenburg_id = 740000002

trips = resrobot.trips(umea_id, gothenburg_id)

len(trips["Trip"])
# Out:
# 6

# %%
trips["Trip"][2]["LegList"]
# Out:
# {'Leg': [{'Origin': {'name': 'Umeå Centralstation',
#     'type': 'ST',
#     'id': 'A=1@O=Umeå Centralstation@X=20266810@Y=63830064@U=1@L=740000190@',
#     'extId': '740000190',
#     'lon': 20.26681,
#     'lat': 63.830064,
#     'routeIdx': 0,
#     'prognosisType': 'PROGNOSED',
#     'time': '12:37:00',
#     'date': '2025-01-12',
#     'minimumChangeDuration': 'PT10M'},
#    'Destination': {'name': 'Sundsvall Centralstation',
#     'type': 'ST',
#     'id': 'A=1@O=Sundsvall Centralstation@X=17315633@Y=62386873@U=1@L=740000130@',
#     'extId': '740000130',
#     'lon': 17.315633,
#     'lat': 62.386873,
#     'routeIdx': 11,
#     'prognosisType': 'PROGNOSED',
#     'time': '15:40:00',
#     'date': '2025-01-12',
#     'minimumChangeDuration': 'PT10M'},
#    'Notes': {'Note': [{'value': 'Endast 2 klass',
#       'key': 'AA',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 11,
#       'txtN': 'Endast 2 klass'},
#      {'value': 'Ej reservering',
#       'key': 'AE',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 11,
#       'txtN': 'Ej reservering'},
#      {'value': 'Rullstolslyft',
#       'key': 'AN',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 11,
#       'txtN': 'Rullstolslyft'},
#      {'value': 'WiFi',
#       'key': 'AW',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 11,
#       'txtN': 'WiFi'},
#      {'value': 'EU förordning 2021/782',
#       'key': 'EJ',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 11,
#       'txtN': 'EU förordning 2021/782'},
#      {'value': 'Eluttag vid sittplats',
#       'key': 'EL',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 11,
#       'txtN': 'Eluttag vid sittplats'},
#      {'value': 'Cyklar tillåtna',
#       'key': 'FB',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 11,
#       'txtN': 'Cyklar tillåtna'},
#      {'value': 'Kafé',
#       'key': 'SK',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 11,
#       'txtN': 'Kafé'}]},
#    'JourneyDetailRef': {'ref': '1|60648|0|1|12012025'},
#    'JourneyStatus': 'P',
#    'Product': [{'icon': {'res': 'prod_gen'},
#      'operatorInfo': {'name': 'Norrtåg',
#       'nameS': '513',
#       'nameN': '513',
#       'nameL': 'Norrtåg',
#       'id': '513'},
#      'name': 'Regional Tåg 7411',
#      'internalName': 'Regional Tåg 7411',
#      'displayNumber': '7411',
#      'num': '7411',
#      'line': '7411',
#      'lineId': '1513003500012',
#      'catOut': 'JRE',
#      'catIn': 'JRE',
#      'catCode': '2',
#      'cls': '4',
#      'catOutS': 'JRE',
#      'catOutL': 'Regional Tåg',
#      'operatorCode': '513',
#      'operator': 'Norrtåg',
#      'admin': '513___',
#      'routeIdxFrom': 0,
#      'routeIdxTo': 11,
#      'matchId': '7403;35;63782'}],
#    'Stops': {'Stop': [{'name': 'Umeå Centralstation',
#       'id': 'A=1@O=Umeå Centralstation@X=20266810@Y=63830064@U=1@L=740000190@',
#       'extId': '740000190',
#       'routeIdx': 0,
#       'lon': 20.26681,
#       'lat': 63.830064,
#       'depPrognosisType': 'PROGNOSED',
#       'depTime': '12:37:00',
#       'depDate': '2025-01-12',
#       'depDir': 'Sundsvall Centralstation',
#       'minimumChangeDuration': 'PT10M'},
#      {'Notes': {'Note': [{'value': 'Stannar endast för påstigande',
#          'key': 'text.realtime.stop.exit.disabled',
#          'type': 'R',
#          'txtN': 'Stannar endast för påstigande'}]},
#       'name': 'Umeå Östra station',
#       'id': 'A=1@O=Umeå Östra station@X=20293454@Y=63817659@U=1@L=740001581@',
#       'extId': '740001581',
#       'routeIdx': 1,
#       'lon': 20.293454,
#       'lat': 63.817659,
#       'depTime': '12:42:00',
#       'depDate': '2025-01-12',
#       'alighting': False,
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Hörnefors Resecentrum/Station (Umeå kn)',
#       'id': 'A=1@O=Hörnefors Resecentrum/Station (Umeå kn)@X=19908464@Y=63632661@U=1@L=740001582@',
#       'extId': '740001582',
#       'routeIdx': 2,
#       'lon': 19.908464,
#       'lat': 63.632661,
#       'depTime': '12:56:00',
#       'depDate': '2025-01-12',
#       'arrTime': '12:56:00',
#       'arrDate': '2025-01-12',
#       'minimumChangeDuration': 'PT5M'},
#      {'name': 'Nordmaling Resecentrum/Station (Nordmaling-AC kn)',
#       'id': 'A=1@O=Nordmaling Resecentrum/Station (Nordmaling-AC kn)@X=19486285@Y=63578303@U=1@L=740001583@',
#       'extId': '740001583',
#       'routeIdx': 3,
#       'lon': 19.486285,
#       'lat': 63.578303,
#       'depTime': '13:07:00',
#       'depDate': '2025-01-12',
#       'arrTime': '13:07:00',
#       'arrDate': '2025-01-12',
#       'minimumChangeDuration': 'PT5M'},
#      {'name': 'Husum station (Örnsköldsvik kn)',
#       'id': 'A=1@O=Husum station (Örnsköldsvik kn)@X=19155725@Y=63343909@U=1@L=740001584@',
#       'extId': '740001584',
#       'routeIdx': 4,
#       'lon': 19.155725,
#       'lat': 63.343909,
#       'depTime': '13:21:00',
#       'depDate': '2025-01-12',
#       'arrTime': '13:21:00',
#       'arrDate': '2025-01-12',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Örnsköldsvik Norra station',
#       'id': 'A=1@O=Örnsköldsvik Norra station@X=18716108@Y=63303035@U=1@L=740001569@',
#       'extId': '740001569',
#       'routeIdx': 5,
#       'lon': 18.716108,
#       'lat': 63.303035,
#       'depTime': '13:33:00',
#       'depDate': '2025-01-12',
#       'arrTime': '13:33:00',
#       'arrDate': '2025-01-12',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Örnsköldsvik Centralstation',
#       'id': 'A=1@O=Örnsköldsvik Centralstation@X=18704305@Y=63289282@U=1@L=740001570@',
#       'extId': '740001570',
#       'routeIdx': 6,
#       'lon': 18.704305,
#       'lat': 63.289282,
#       'depTime': '13:36:00',
#       'depDate': '2025-01-12',
#       'arrTime': '13:36:00',
#       'arrDate': '2025-01-12',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Kramfors station',
#       'id': 'A=1@O=Kramfors station@X=17778182@Y=62929111@U=1@L=740000220@',
#       'extId': '740000220',
#       'routeIdx': 7,
#       'lon': 17.778182,
#       'lat': 62.929111,
#       'depTime': '14:18:00',
#       'depDate': '2025-01-12',
#       'arrTime': '14:18:00',
#       'arrDate': '2025-01-12',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Härnösand station',
#       'id': 'A=1@O=Härnösand station@X=17928635@Y=62635182@U=1@L=740000253@',
#       'extId': '740000253',
#       'routeIdx': 8,
#       'lon': 17.928635,
#       'lat': 62.635182,
#       'depTime': '14:42:00',
#       'depDate': '2025-01-12',
#       'arrTime': '14:42:00',
#       'arrDate': '2025-01-12',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Timrå station',
#       'id': 'A=1@O=Timrå station@X=17330546@Y=62486392@U=1@L=740000242@',
#       'extId': '740000242',
#       'routeIdx': 9,
#       'lon': 17.330546,
#       'lat': 62.486392,
#       'depTime': '15:22:00',
#       'depDate': '2025-01-12',
#       'arrTime': '15:22:00',
#       'arrDate': '2025-01-12',
#       'minimumChangeDuration': 'PT10M'},
#      {'Notes': {'Note': [{'value': 'Stannar endast för avstigande',
#          'key': 'text.realtime.stop.entry.disabled',
#          'type': 'R',
#          'txtN': 'Stannar endast för avstigande'}]},
#       'name': 'Sundsvall Västra station',
#       'id': 'A=1@O=Sundsvall Västra station@X=17291668@Y=62389893@U=1@L=740020045@',
#       'extId': '740020045',
#       'routeIdx': 10,
#       'lon': 17.291668,
#       'lat': 62.389893,
#       'arrTime': '15:36:00',
#       'arrDate': '2025-01-12',
#       'boarding': False,
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Sundsvall Centralstation',
#       'id': 'A=1@O=Sundsvall Centralstation@X=17315633@Y=62386873@U=1@L=740000130@',
#       'extId': '740000130',
#       'routeIdx': 11,
#       'lon': 17.315633,
#       'lat': 62.386873,
#       'arrPrognosisType': 'PROGNOSED',
#       'arrTime': '15:40:00',
#       'arrDate': '2025-01-12',
#       'minimumChangeDuration': 'PT10M'}]},
#    'JourneyDetail': {'ref': '1|60648|0|1|12012025',
#     'dayOfOperation': '2025-01-12'},
#    'id': '0',
#    'idx': 0,
#    'name': 'Regional Tåg 7411',
#    'number': '7411',
#    'category': 'JRE',
#    'type': 'JNY',
#    'reachable': True,
#    'waitingState': 'UNDEF',
#    'direction': 'Sundsvall Centralstation',
#    'directionFlag': '1',
#    'duration': 'PT3H3M',
#    'minimumChangeDuration': 'PT10M'},
#   {'Origin': {'name': 'Sundsvall Centralstation',
#     'type': 'ST',
#     'id': 'A=1@O=Sundsvall Centralstation@X=17315633@Y=62386873@U=1@L=740000130@',
#     'extId': '740000130',
#     'lon': 17.315633,
#     'lat': 62.386873,
#     'routeIdx': 0,
#     'prognosisType': 'PROGNOSED',
#     'time': '16:04:00',
#     'date': '2025-01-12',
#     'minimumChangeDuration': 'PT10M'},
#    'Destination': {'name': 'Stockholm Centralstation',
#     'type': 'ST',
#     'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#     'extId': '740000001',
#     'lon': 18.058151,
#     'lat': 59.330136,
#     'routeIdx': 6,
#     'prognosisType': 'PROGNOSED',
#     'time': '19:37:00',
#     'date': '2025-01-12',
#     'minimumChangeDuration': 'PT20M'},
#    'Notes': {'Note': [{'value': 'SJ3000',
#       'key': 'V3',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 6,
#       'txtN': 'SJ3000'},
#      {'value': 'Mat 1 klass',
#       'key': 'A1',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 6,
#       'txtN': 'Mat 1 klass'},
#      {'value': 'Bistrovagn',
#       'key': 'AD',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 6,
#       'txtN': 'Bistrovagn'},
#      {'value': 'Obligatorisk platsbokning',
#       'key': 'AF',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 6,
#       'txtN': 'Obligatorisk platsbokning'},
#      {'value': 'Rullstolslyft',
#       'key': 'AN',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 6,
#       'txtN': 'Rullstolslyft'},
#      {'value': 'WiFi',
#       'key': 'AW',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 6,
#       'txtN': 'WiFi'},
#      {'value': '2 klass lugn',
#       'key': 'BL',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 6,
#       'txtN': '2 klass lugn'},
#      {'value': 'EU förordning 2021/782',
#       'key': 'EJ',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 6,
#       'txtN': 'EU förordning 2021/782'},
#      {'value': 'Maträtt',
#       'key': 'SM',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 6,
#       'txtN': 'Maträtt'},
#      {'value': '1 klass med extra komfort',
#       'key': 'SU',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 6,
#       'txtN': '1 klass med extra komfort'},
#      {'value': 'Kaffebuffé 1 klass',
#       'key': 'SZ',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 6,
#       'txtN': 'Kaffebuffé 1 klass'}]},
#    'JourneyDetailRef': {'ref': '1|121593|0|1|12012025'},
#    'JourneyStatus': 'P',
#    'Product': [{'icon': {'res': 'prod_gen'},
#      'operatorInfo': {'name': 'SJ',
#       'nameS': '74',
#       'nameN': '74',
#       'nameL': 'SJ',
#       'id': '74'},
#      'name': 'Snabbtåg 583',
#      'internalName': 'Snabbtåg 583',
#      'displayNumber': '583',
#      'num': '583',
#      'line': '583',
#      'lineId': '1074058300001',
#      'catOut': 'JST',
#      'catIn': 'JST',
#      'catCode': '1',
#      'cls': '2',
#      'catOutS': 'JST',
#      'catOutL': 'Snabbtåg',
#      'operatorCode': '74',
#      'operator': 'SJ',
#      'admin': '074___',
#      'routeIdxFrom': 0,
#      'routeIdxTo': 6,
#      'matchId': '583;583;14341'}],
#    'Stops': {'Stop': [{'name': 'Sundsvall Centralstation',
#       'id': 'A=1@O=Sundsvall Centralstation@X=17315633@Y=62386873@U=1@L=740000130@',
#       'extId': '740000130',
#       'routeIdx': 0,
#       'lon': 17.315633,
#       'lat': 62.386873,
#       'depPrognosisType': 'PROGNOSED',
#       'depTime': '16:04:00',
#       'depDate': '2025-01-12',
#       'depDir': 'Stockholm Centralstation',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Hudiksvall station',
#       'id': 'A=1@O=Hudiksvall station@X=17109034@Y=61724494@U=1@L=740000187@',
#       'extId': '740000187',
#       'routeIdx': 1,
#       'lon': 17.109034,
#       'lat': 61.724494,
#       'depTime': '17:00:00',
#       'depDate': '2025-01-12',
#       'arrTime': '17:00:00',
#       'arrDate': '2025-01-12',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Söderhamn station',
#       'id': 'A=1@O=Söderhamn station@X=17035682@Y=61299600@U=1@L=740000154@',
#       'extId': '740000154',
#       'routeIdx': 2,
#       'lon': 17.035682,
#       'lat': 61.2996,
#       'depTime': '17:28:00',
#       'depDate': '2025-01-12',
#       'arrTime': '17:28:00',
#       'arrDate': '2025-01-12',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Gävle Centralstation',
#       'id': 'A=1@O=Gävle Centralstation@X=17151221@Y=60676118@U=1@L=740000210@',
#       'extId': '740000210',
#       'routeIdx': 3,
#       'lon': 17.151221,
#       'lat': 60.676118,
#       'depTime': '18:14:00',
#       'depDate': '2025-01-12',
#       'arrTime': '18:10:00',
#       'arrDate': '2025-01-12',
#       'minimumChangeDuration': 'PT10M'},
#      {'Notes': {'Note': [{'value': 'Stannar endast för avstigande',
#          'key': 'text.realtime.stop.entry.disabled',
#          'type': 'R',
#          'txtN': 'Stannar endast för avstigande'}]},
#       'name': 'Uppsala Centralstation',
#       'id': 'A=1@O=Uppsala Centralstation@X=17646086@Y=59858531@U=1@L=740000005@',
#       'extId': '740000005',
#       'routeIdx': 4,
#       'lon': 17.646086,
#       'lat': 59.858531,
#       'arrTime': '18:58:00',
#       'arrDate': '2025-01-12',
#       'boarding': False,
#       'minimumChangeDuration': 'PT10M'},
#      {'Notes': {'Note': [{'value': 'Stannar endast för avstigande',
#          'key': 'text.realtime.stop.entry.disabled',
#          'type': 'R',
#          'txtN': 'Stannar endast för avstigande'}]},
#       'name': 'Arlanda Centralstation (Sigtuna kn)',
#       'id': 'A=1@O=Arlanda Centralstation (Sigtuna kn)@X=17929201@Y=59649469@U=1@L=740000556@',
#       'extId': '740000556',
#       'routeIdx': 5,
#       'lon': 17.929201,
#       'lat': 59.649469,
#       'arrTime': '19:19:00',
#       'arrDate': '2025-01-12',
#       'boarding': False,
#       'minimumChangeDuration': 'PT2H'},
#      {'name': 'Stockholm Centralstation',
#       'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#       'extId': '740000001',
#       'routeIdx': 6,
#       'lon': 18.058151,
#       'lat': 59.330136,
#       'arrPrognosisType': 'PROGNOSED',
#       'arrTime': '19:37:00',
#       'arrDate': '2025-01-12',
#       'minimumChangeDuration': 'PT20M'}]},
#    'JourneyDetail': {'ref': '1|121593|0|1|12012025',
#     'dayOfOperation': '2025-01-12'},
#    'id': '1',
#    'idx': 1,
#    'name': 'Snabbtåg 583',
#    'number': '583',
#    'category': 'JST',
#    'type': 'JNY',
#    'reachable': True,
#    'waitingState': 'UNDEF',
#    'direction': 'Stockholm Centralstation',
#    'directionFlag': '1',
#    'duration': 'PT3H33M',
#    'minimumChangeDuration': 'PT20M'},
#   {'Origin': {'name': 'Stockholm Centralstation',
#     'type': 'ST',
#     'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#     'extId': '740000001',
#     'lon': 18.058151,
#     'lat': 59.330136,
#     'routeIdx': 0,
#     'prognosisType': 'PROGNOSED',
#     'time': '20:12:00',
#     'date': '2025-01-12',
#     'minimumChangeDuration': 'PT20M'},
#    'Destination': {'name': 'Göteborg Centralstation',
#     'type': 'ST',
#     'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#     'extId': '740000002',
#     'lon': 11.973479,
#     'lat': 57.708895,
#     'routeIdx': 3,
#     'prognosisType': 'PROGNOSED',
#     'time': '23:41:00',
#     'date': '2025-01-12',
#     'minimumChangeDuration': 'PT15M'},
#    'Notes': {'Note': [{'value': 'X2000',
#       'key': 'VX',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'X2000'},
#      {'value': 'Mat 1 klass',
#       'key': 'A1',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'Mat 1 klass'},
#      {'value': 'Bistrovagn',
#       'key': 'AD',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'Bistrovagn'},
#      {'value': 'Obligatorisk platsbokning',
#       'key': 'AF',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'Obligatorisk platsbokning'},
#      {'value': 'Rullstolslyft',
#       'key': 'AN',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'Rullstolslyft'},
#      {'value': 'WiFi',
#       'key': 'AW',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'WiFi'},
#      {'value': '2 klass lugn',
#       'key': 'BL',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': '2 klass lugn'},
#      {'value': 'EU förordning 2021/782',
#       'key': 'EJ',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'EU förordning 2021/782'},
#      {'value': 'Maträtt',
#       'key': 'SM',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'Maträtt'},
#      {'value': '1 klass med extra komfort',
#       'key': 'SU',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': '1 klass med extra komfort'},
#      {'value': 'Kaffebuffé 1 klass',
#       'key': 'SZ',
#       'type': 'A',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 3,
#       'txtN': 'Kaffebuffé 1 klass'}]},
#    'JourneyDetailRef': {'ref': '1|111666|0|1|12012025'},
#    'JourneyStatus': 'P',
#    'Product': [{'icon': {'res': 'prod_gen'},
#      'operatorInfo': {'name': 'SJ',
#       'nameS': '74',
#       'nameN': '74',
#       'nameL': 'SJ',
#       'id': '74'},
#      'name': 'Snabbtåg 449',
#      'internalName': 'Snabbtåg 449',
#      'displayNumber': '449',
#      'num': '449',
#      'line': '449',
#      'lineId': '1074044900001',
#      'catOut': 'JST',
#      'catIn': 'JST',
#      'catCode': '1',
#      'cls': '2',
#      'catOutS': 'JST',
#      'catOutL': 'Snabbtåg',
#      'operatorCode': '74',
#      'operator': 'SJ',
#      'admin': '074___',
#      'routeIdxFrom': 0,
#      'routeIdxTo': 3,
#      'matchId': '449;449;56589'}],
#    'Stops': {'Stop': [{'name': 'Stockholm Centralstation',
#       'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#       'extId': '740000001',
#       'routeIdx': 0,
#       'lon': 18.058151,
#       'lat': 59.330136,
#       'depPrognosisType': 'PROGNOSED',
#       'depTime': '20:12:00',
#       'depDate': '2025-01-12',
#       'depDir': 'Göteborg Centralstation',
#       'minimumChangeDuration': 'PT20M'},
#      {'name': 'Katrineholm Centralstation',
#       'id': 'A=1@O=Katrineholm Centralstation@X=16208324@Y=58996591@U=1@L=740000166@',
#       'extId': '740000166',
#       'routeIdx': 1,
#       'lon': 16.208324,
#       'lat': 58.996591,
#       'depTime': '21:04:00',
#       'depDate': '2025-01-12',
#       'arrTime': '21:03:00',
#       'arrDate': '2025-01-12',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Skövde Centralstation',
#       'id': 'A=1@O=Skövde Centralstation@X=13853195@Y=58390898@U=1@L=740000008@',
#       'extId': '740000008',
#       'routeIdx': 2,
#       'lon': 13.853195,
#       'lat': 58.390898,
#       'depTime': '22:21:00',
#       'depDate': '2025-01-12',
#       'arrTime': '22:21:00',
#       'arrDate': '2025-01-12',
#       'minimumChangeDuration': 'PT10M'},
#      {'name': 'Göteborg Centralstation',
#       'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#       'extId': '740000002',
#       'routeIdx': 3,
#       'lon': 11.973479,
#       'lat': 57.708895,
#       'arrPrognosisType': 'PROGNOSED',
#       'arrTime': '23:41:00',
#       'arrDate': '2025-01-12',
#       'minimumChangeDuration': 'PT15M'}]},
#    'JourneyDetail': {'ref': '1|111666|0|1|12012025',
#     'dayOfOperation': '2025-01-12'},
#    'id': '2',
#    'idx': 2,
#    'name': 'Snabbtåg 449',
#    'number': '449',
#    'category': 'JST',
#    'type': 'JNY',
#    'reachable': True,
#    'waitingState': 'UNDEF',
#    'direction': 'Göteborg Centralstation',
#    'directionFlag': '1',
#    'duration': 'PT3H29M'}]}

# %%
import pandas as pd 

# pd.DataFrame(trips["Trip"])
legs = []

for trip in trips.get("Trip"):
    legs.append(trip.get("LegList").get("Leg"))

# Umeå -> Stockholm
legs[0][0]["Origin"], legs[0][0]["Destination"]
# Out:
# ({'name': 'Umeå Centralstation',
#   'type': 'ST',
#   'id': 'A=1@O=Umeå Centralstation@X=20266810@Y=63830064@U=1@L=740000190@',
#   'extId': '740000190',
#   'lon': 20.26681,
#   'lat': 63.830064,
#   'routeIdx': 0,
#   'prognosisType': 'PROGNOSED',
#   'time': '10:37:00',
#   'date': '2025-01-12',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Sundsvall Centralstation',
#   'type': 'ST',
#   'id': 'A=1@O=Sundsvall Centralstation@X=17315633@Y=62386873@U=1@L=740000130@',
#   'extId': '740000130',
#   'lon': 17.315633,
#   'lat': 62.386873,
#   'routeIdx': 12,
#   'prognosisType': 'PROGNOSED',
#   'time': '13:40:00',
#   'date': '2025-01-12',
#   'minimumChangeDuration': 'PT10M'})

# %%
# Stockholm -> Göteborg
legs[0][1]["Origin"], legs[0][1]["Destination"]
# Out:
# ({'name': 'Sundsvall Centralstation',
#   'type': 'ST',
#   'id': 'A=1@O=Sundsvall Centralstation@X=17315633@Y=62386873@U=1@L=740000130@',
#   'extId': '740000130',
#   'lon': 17.315633,
#   'lat': 62.386873,
#   'routeIdx': 0,
#   'prognosisType': 'PROGNOSED',
#   'time': '14:04:00',
#   'date': '2025-01-12',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Stockholm Centralstation',
#   'type': 'ST',
#   'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#   'extId': '740000001',
#   'lon': 18.058151,
#   'lat': 59.330136,
#   'routeIdx': 6,
#   'prognosisType': 'PROGNOSED',
#   'time': '17:37:00',
#   'date': '2025-01-12',
#   'minimumChangeDuration': 'PT20M'})

# %%
next_available_trip = legs[0]
df = pd.DataFrame(next_available_trip)
df
# Out:
#                                               Origin  \
# 0  {'name': 'Umeå Centralstation', 'type': 'ST', ...
# 1  {'name': 'Sundsvall Centralstation', 'type': '...
# 2  {'name': 'Stockholm Centralstation', 'type': '...
#
#                                          Destination  \
# 0  {'name': 'Sundsvall Centralstation', 'type': '...
# 1  {'name': 'Stockholm Centralstation', 'type': '...
# 2  {'name': 'Göteborg Centralstation', 'type': 'S...
#
#                                                Notes  \
# 0  {'Note': [{'value': 'Endast 2 klass', 'key': '...
# 1  {'Note': [{'value': 'SJ3000', 'key': 'V3', 'ty...
# 2  {'Note': [{'value': 'X2000', 'key': 'VX', 'typ...
#
#                   JourneyDetailRef JourneyStatus  \
# 0  {'ref': '1|60633|0|1|12012025'}             P
# 1  {'ref': '1|27278|0|1|12012025'}             P
# 2  {'ref': '1|98120|0|1|12012025'}             P
#
#                                              Product  \
# 0  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 1  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 2  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
#
#                                                Stops  \
# 0  {'Stop': [{'name': 'Umeå Centralstation', 'id'...
# 1  {'Stop': [{'name': 'Sundsvall Centralstation',...
# 2  {'Stop': [{'name': 'Stockholm Centralstation',...
#
#                                        JourneyDetail id  idx  \
# 0  {'ref': '1|60633|0|1|12012025', 'dayOfOperatio...  0    0
# 1  {'ref': '1|27278|0|1|12012025', 'dayOfOperatio...  1    1
# 2  {'ref': '1|98120|0|1|12012025', 'dayOfOperatio...  2    2
#
#                 name number category type  reachable waitingState  \
# 0  Regional Tåg 7409   7409      JRE  JNY       True        UNDEF
# 1       Snabbtåg 579    579      JST  JNY       True        UNDEF
# 2       Snabbtåg 445    445      JST  JNY       True        UNDEF
#
#                   direction directionFlag duration minimumChangeDuration
# 0  Sundsvall Centralstation             1   PT3H3M                 PT10M
# 1  Stockholm Centralstation             1  PT3H33M                 PT20M
# 2   Göteborg Centralstation             1  PT3H34M                   NaN

# %%
df_trip = df[["name", "Stops"]]
df_trip
# Out:
#                 name                                              Stops
# 0  Regional Tåg 7409  {'Stop': [{'name': 'Umeå Centralstation', 'id'...
# 1       Snabbtåg 579  {'Stop': [{'name': 'Sundsvall Centralstation',...
# 2       Snabbtåg 445  {'Stop': [{'name': 'Stockholm Centralstation',...

# %%
df_trip["Stops"]
# Out:
# 0    {'Stop': [{'name': 'Umeå Centralstation', 'id'...
# 1    {'Stop': [{'name': 'Sundsvall Centralstation',...
# 2    {'Stop': [{'name': 'Stockholm Centralstation',...
# Name: Stops, dtype: object

# %%
all_stops = pd.json_normalize(df["Stops"], "Stop")
all_stops.head()
# Out:
#                                                 name  \
# 0                                Umeå Centralstation
# 1                                 Umeå Östra station
# 2            Hörnefors Resecentrum/Station (Umeå kn)
# 3  Nordmaling Resecentrum/Station (Nordmaling-AC kn)
# 4                    Husum station (Örnsköldsvik kn)
#
#                                                   id      extId  routeIdx  \
# 0  A=1@O=Umeå Centralstation@X=20266810@Y=6383006...  740000190         0
# 1  A=1@O=Umeå Östra station@X=20293454@Y=63817659...  740001581         1
# 2  A=1@O=Hörnefors Resecentrum/Station (Umeå kn)@...  740001582         2
# 3  A=1@O=Nordmaling Resecentrum/Station (Nordmali...  740001583         3
# 4  A=1@O=Husum station (Örnsköldsvik kn)@X=191557...  740001584         4
#
#          lon        lat depPrognosisType   depTime     depDate  \
# 0  20.266810  63.830064        PROGNOSED  10:37:00  2025-01-12
# 1  20.293454  63.817659              NaN  10:42:00  2025-01-12
# 2  19.908464  63.632661              NaN  10:56:00  2025-01-12
# 3  19.486285  63.578303              NaN  11:07:00  2025-01-12
# 4  19.155725  63.343909              NaN  11:21:00  2025-01-12
#
#                      depDir minimumChangeDuration alighting  \
# 0  Sundsvall Centralstation                 PT10M       NaN
# 1                       NaN                 PT10M     False
# 2                       NaN                  PT5M       NaN
# 3                       NaN                  PT5M       NaN
# 4                       NaN                 PT10M       NaN
#
#                                           Notes.Note   arrTime     arrDate  \
# 0                                                NaN       NaN         NaN
# 1  [{'value': 'Stannar endast för påstigande', 'k...       NaN         NaN
# 2                                                NaN  10:56:00  2025-01-12
# 3                                                NaN  11:07:00  2025-01-12
# 4                                                NaN  11:21:00  2025-01-12
#
#   boarding arrPrognosisType
# 0      NaN              NaN
# 1      NaN              NaN
# 2      NaN              NaN
# 3      NaN              NaN
# 4      NaN              NaN

# %%
stops = all_stops[["name", "depTime", "depDate", "lon", "lat"]]
stops
# Out:
#                                                  name   depTime     depDate  \
# 0                                 Umeå Centralstation  10:37:00  2025-01-12
# 1                                  Umeå Östra station  10:42:00  2025-01-12
# 2             Hörnefors Resecentrum/Station (Umeå kn)  10:56:00  2025-01-12
# 3   Nordmaling Resecentrum/Station (Nordmaling-AC kn)  11:07:00  2025-01-12
# 4                     Husum station (Örnsköldsvik kn)  11:21:00  2025-01-12
# 5                          Örnsköldsvik Norra station  11:33:00  2025-01-12
# 6                         Örnsköldsvik Centralstation  11:42:00  2025-01-12
# 7         Västeraspby stn/Höga Kust flp (Kramfors kn)  12:12:00  2025-01-12
# 8                                    Kramfors station  12:24:00  2025-01-12
# 9                                   Härnösand station  12:46:00  2025-01-12
# 10                                      Timrå station  13:22:00  2025-01-12
# 11                           Sundsvall Västra station       NaN         NaN
# 12                           Sundsvall Centralstation       NaN         NaN
# 13                           Sundsvall Centralstation  14:04:00  2025-01-12
# 14                                 Hudiksvall station  15:00:00  2025-01-12
# 15                                  Söderhamn station  15:28:00  2025-01-12
# 16                               Gävle Centralstation  16:14:00  2025-01-12
# 17                             Uppsala Centralstation       NaN         NaN
# 18                Arlanda Centralstation (Sigtuna kn)       NaN         NaN
# 19                           Stockholm Centralstation       NaN         NaN
# 20                           Stockholm Centralstation  18:07:00  2025-01-12
# 21                         Katrineholm Centralstation  19:00:00  2025-01-12
# 22                              Skövde Centralstation  20:18:00  2025-01-12
# 23                                 Herrljunga station  20:45:00  2025-01-12
# 24                            Göteborg Centralstation       NaN         NaN
#
#           lon        lat
# 0   20.266810  63.830064
# 1   20.293454  63.817659
# 2   19.908464  63.632661
# 3   19.486285  63.578303
# 4   19.155725  63.343909
# 5   18.716108  63.303035
# 6   18.704305  63.289282
# 7   17.744724  63.052713
# 8   17.778182  62.929111
# 9   17.928635  62.635182
# 10  17.330546  62.486392
# 11  17.291668  62.389893
# 12  17.315633  62.386873
# 13  17.315633  62.386873
# 14  17.109034  61.724494
# 15  17.035682  61.299600
# 16  17.151221  60.676118
# 17  17.646086  59.858531
# 18  17.929201  59.649469
# 19  18.058151  59.330136
# 20  18.058151  59.330136
# 21  16.208324  58.996591
# 22  13.853195  58.390898
# 23  13.021279  58.079188
# 24  11.973479  57.708895

# %%
stops = stops.drop_duplicates(subset="name").reset_index(drop=True)
stops
# Out:
#                                                  name   depTime     depDate  \
# 0                                 Umeå Centralstation  10:37:00  2025-01-12
# 1                                  Umeå Östra station  10:42:00  2025-01-12
# 2             Hörnefors Resecentrum/Station (Umeå kn)  10:56:00  2025-01-12
# 3   Nordmaling Resecentrum/Station (Nordmaling-AC kn)  11:07:00  2025-01-12
# 4                     Husum station (Örnsköldsvik kn)  11:21:00  2025-01-12
# 5                          Örnsköldsvik Norra station  11:33:00  2025-01-12
# 6                         Örnsköldsvik Centralstation  11:42:00  2025-01-12
# 7         Västeraspby stn/Höga Kust flp (Kramfors kn)  12:12:00  2025-01-12
# 8                                    Kramfors station  12:24:00  2025-01-12
# 9                                   Härnösand station  12:46:00  2025-01-12
# 10                                      Timrå station  13:22:00  2025-01-12
# 11                           Sundsvall Västra station       NaN         NaN
# 12                           Sundsvall Centralstation       NaN         NaN
# 13                                 Hudiksvall station  15:00:00  2025-01-12
# 14                                  Söderhamn station  15:28:00  2025-01-12
# 15                               Gävle Centralstation  16:14:00  2025-01-12
# 16                             Uppsala Centralstation       NaN         NaN
# 17                Arlanda Centralstation (Sigtuna kn)       NaN         NaN
# 18                           Stockholm Centralstation       NaN         NaN
# 19                         Katrineholm Centralstation  19:00:00  2025-01-12
# 20                              Skövde Centralstation  20:18:00  2025-01-12
# 21                                 Herrljunga station  20:45:00  2025-01-12
# 22                            Göteborg Centralstation       NaN         NaN
#
#           lon        lat
# 0   20.266810  63.830064
# 1   20.293454  63.817659
# 2   19.908464  63.632661
# 3   19.486285  63.578303
# 4   19.155725  63.343909
# 5   18.716108  63.303035
# 6   18.704305  63.289282
# 7   17.744724  63.052713
# 8   17.778182  62.929111
# 9   17.928635  62.635182
# 10  17.330546  62.486392
# 11  17.291668  62.389893
# 12  17.315633  62.386873
# 13  17.109034  61.724494
# 14  17.035682  61.299600
# 15  17.151221  60.676118
# 16  17.646086  59.858531
# 17  17.929201  59.649469
# 18  18.058151  59.330136
# 19  16.208324  58.996591
# 20  13.853195  58.390898
# 21  13.021279  58.079188
# 22  11.973479  57.708895

# %%
stops
# Out:
#                                                  name   depTime     depDate  \
# 0                                 Umeå Centralstation  10:37:00  2025-01-12
# 1                                  Umeå Östra station  10:42:00  2025-01-12
# 2             Hörnefors Resecentrum/Station (Umeå kn)  10:56:00  2025-01-12
# 3   Nordmaling Resecentrum/Station (Nordmaling-AC kn)  11:07:00  2025-01-12
# 4                     Husum station (Örnsköldsvik kn)  11:21:00  2025-01-12
# 5                          Örnsköldsvik Norra station  11:33:00  2025-01-12
# 6                         Örnsköldsvik Centralstation  11:42:00  2025-01-12
# 7         Västeraspby stn/Höga Kust flp (Kramfors kn)  12:12:00  2025-01-12
# 8                                    Kramfors station  12:24:00  2025-01-12
# 9                                   Härnösand station  12:46:00  2025-01-12
# 10                                      Timrå station  13:22:00  2025-01-12
# 11                           Sundsvall Västra station       NaN         NaN
# 12                           Sundsvall Centralstation       NaN         NaN
# 13                                 Hudiksvall station  15:00:00  2025-01-12
# 14                                  Söderhamn station  15:28:00  2025-01-12
# 15                               Gävle Centralstation  16:14:00  2025-01-12
# 16                             Uppsala Centralstation       NaN         NaN
# 17                Arlanda Centralstation (Sigtuna kn)       NaN         NaN
# 18                           Stockholm Centralstation       NaN         NaN
# 19                         Katrineholm Centralstation  19:00:00  2025-01-12
# 20                              Skövde Centralstation  20:18:00  2025-01-12
# 21                                 Herrljunga station  20:45:00  2025-01-12
# 22                            Göteborg Centralstation       NaN         NaN
#
#           lon        lat
# 0   20.266810  63.830064
# 1   20.293454  63.817659
# 2   19.908464  63.632661
# 3   19.486285  63.578303
# 4   19.155725  63.343909
# 5   18.716108  63.303035
# 6   18.704305  63.289282
# 7   17.744724  63.052713
# 8   17.778182  62.929111
# 9   17.928635  62.635182
# 10  17.330546  62.486392
# 11  17.291668  62.389893
# 12  17.315633  62.386873
# 13  17.109034  61.724494
# 14  17.035682  61.299600
# 15  17.151221  60.676118
# 16  17.646086  59.858531
# 17  17.929201  59.649469
# 18  18.058151  59.330136
# 19  16.208324  58.996591
# 20  13.853195  58.390898
# 21  13.021279  58.079188
# 22  11.973479  57.708895

# %%
import folium

geographical_map = folium.Map(location=[stops["lat"].mean(), stops["lon"].mean()], zoom_start=6)

for _, row in stops.iterrows():
    folium.Marker(
        location=[row["lat"], row["lon"]],
        popup=f"{row['name']}<br>{row['depTime']}<br>{row['depDate']}",
    ).add_to(geographical_map)

geographical_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_20075ec8983376d20b107da9f34d2288 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_20075ec8983376d20b107da9f34d2288&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_20075ec8983376d20b107da9f34d2288 = L.map(
#                 &quot;map_20075ec8983376d20b107da9f34d2288&quot;,
#                 {
#                     center: [61.58213030434783, 17.474182217391302],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_87f0c8060a7ac77b7d12def054778d26 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_87f0c8060a7ac77b7d12def054778d26.addTo(map_20075ec8983376d20b107da9f34d2288);
#
#
#             var marker_19234207b0526af5ca3506c385328101 = L.marker(
#                 [63.830064, 20.26681],
#                 {
# }
#             ).addTo(map_20075ec8983376d20b107da9f34d2288);
#
#
#         var popup_150377743c4faf906780af7347e0820a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0e9d47b90c16b9cd2a69fbdb18186fa = $(`&lt;div id=&quot;html_b0e9d47b90c16b9cd2a69fbdb18186fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Umeå Centralstation&lt;br&gt;10:37:00&lt;br&gt;2025-01-12&lt;/div&gt;`)[0];
#                 popup_150377743c4faf906780af7347e0820a.setContent(html_b0e9d47b90c16b9cd2a69fbdb18186fa);
#
#
#
#         marker_19234207b0526af5ca3506c385328101.bindPopup(popup_150377743c4faf906780af7347e0820a)
#         ;
#
#
#
#
#             var marker_c2592b47da266dd2ce9e985fead1a2f2 = L.marker(
#                 [63.817659, 20.293454],
#                 {
# }
#             ).addTo(map_20075ec8983376d20b107da9f34d2288);
#
#
#         var popup_02110744ab3a47eece84293cc54c339b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5e4ac42583440656338ae0097b3b980 = $(`&lt;div id=&quot;html_e5e4ac42583440656338ae0097b3b980&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Umeå Östra station&lt;br&gt;10:42:00&lt;br&gt;2025-01-12&lt;/div&gt;`)[0];
#                 popup_02110744ab3a47eece84293cc54c339b.setContent(html_e5e4ac42583440656338ae0097b3b980);
#
#
#
#         marker_c2592b47da266dd2ce9e985fead1a2f2.bindPopup(popup_02110744ab3a47eece84293cc54c339b)
#         ;
#
#
#
#
#             var marker_62b79615d4323b6a774d4a28b85f8ab9 = L.marker(
#                 [63.632661, 19.908464],
#                 {
# }
#             ).addTo(map_20075ec8983376d20b107da9f34d2288);
#
#
#         var popup_bca9e5d6a481c565b84a5f560beedf72 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d505e9776b370b0b37a4fce34dc65d16 = $(`&lt;div id=&quot;html_d505e9776b370b0b37a4fce34dc65d16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hörnefors Resecentrum/Station (Umeå kn)&lt;br&gt;10:56:00&lt;br&gt;2025-01-12&lt;/div&gt;`)[0];
#                 popup_bca9e5d6a481c565b84a5f560beedf72.setContent(html_d505e9776b370b0b37a4fce34dc65d16);
#
#
#
#         marker_62b79615d4323b6a774d4a28b85f8ab9.bindPopup(popup_bca9e5d6a481c565b84a5f560beedf72)
#         ;
#
#
#
#
#             var marker_5980681346ec75dfe6e01693d03efabd = L.marker(
#                 [63.578303, 19.486285],
#                 {
# }
#             ).addTo(map_20075ec8983376d20b107da9f34d2288);
#
#
#         var popup_53f90b7893e81b6c08f684c090378d6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a2f70147e91144c9d7c211fa4d2ff0c = $(`&lt;div id=&quot;html_8a2f70147e91144c9d7c211fa4d2ff0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nordmaling Resecentrum/Station (Nordmaling-AC kn)&lt;br&gt;11:07:00&lt;br&gt;2025-01-12&lt;/div&gt;`)[0];
#                 popup_53f90b7893e81b6c08f684c090378d6a.setContent(html_8a2f70147e91144c9d7c211fa4d2ff0c);
#
#
#
#         marker_5980681346ec75dfe6e01693d03efabd.bindPopup(popup_53f90b7893e81b6c08f684c090378d6a)
#         ;
#
#
#
#
#             var marker_c966333621d205da065a337aca8df173 = L.marker(
#                 [63.343909, 19.155725],
#                 {
# }
#             ).addTo(map_20075ec8983376d20b107da9f34d2288);
#
#
#         var popup_14860aaf2a5f43ae38fa4e72fec3d911 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad6408bc6f49f182a3c7469b94b32e46 = $(`&lt;div id=&quot;html_ad6408bc6f49f182a3c7469b94b32e46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Husum station (Örnsköldsvik kn)&lt;br&gt;11:21:00&lt;br&gt;2025-01-12&lt;/div&gt;`)[0];
#                 popup_14860aaf2a5f43ae38fa4e72fec3d911.setContent(html_ad6408bc6f49f
